# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/A-Year-s-Worth-of-Google-Searches/blob/master/Condo_Analyses_DropDown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview

# %% [markdown]
# ### The goal of this file is to be able to drop in MLS data and quickly get a scatter plot where the points reflect the Condition/Appearance and that let's one filter for Bedroom and Bath count.

# %% [markdown]
# # Libraries

# %%
import pandas as pd
from google.colab import drive
import plotly.express as px
import numpy as np
import plotly.graph_objs as go
import plotly.io as pio

# %% [markdown]
# # Options

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DATA/Real_Estate_Data

# %%
condo = pd.read_csv('Annonymous_Condo_data_Nov_23.csv')
condo.head(3)
# Out:
#     Exp_Date           Appearance  Days_On_Market Listing_Date  Listing_Price  \
# 0  1/15/2023                 Mint               9    7/05/2022         188000
# 1  1/07/2023  Description Missing              34    7/07/2022         179999
# 2  1/05/2023  Description Missing              18    7/07/2022         149999
#
#     ML# REO Sold_Price             Style Unit_on_Floor_#   Development  Bath  \
# 0  2286   N     205000  Garden Apartment               1      Lisaberg   1.0
# 1   435   N     172000  Garden Apartment               1  East Melissa   1.0
# 2  5535   N     150000  Garden Apartment               2  East Melissa   1.0
#
#    Bedrooms Contract_Date  count    Year Month_Year  Month
# 0         1    2022-07-22   11.0  2022.0    07-2022      7
# 1         2    2022-08-10   70.0  2022.0    08-2022      8
# 2         1    2022-07-25   70.0  2022.0    07-2022      7

# %%
condo.tail(20)
# Out:
#        Exp_Date           Appearance  Days_On_Market Listing_Date  \
# 938  10/28/2022                 Mint              13    4/28/2022
# 939  07/03/2023  Description Missing              28   01/03/2023
# 940   6/30/2022  Description Missing              36   02/07/2022
# 941  12/26/2023  Description Missing              28    5/25/2023
# 942   6/30/2023  Description Missing              40   09/08/2022
# 943   6/15/2023                 Mint               6   12/15/2022
# 944  08/06/2023  Description Missing              10   03/06/2023
# 945  12/31/2023                 Mint               8   06/02/2023
# 946   3/31/2022                 Mint              13    9/22/2021
# 947  11/30/2022                 Mint              50    5/23/2022
# 948  04/01/2022                 Mint              23   07/01/2021
# 949   8/22/2023                 Good              28    8/23/2022
# 950  12/13/2022                 Good              98    6/21/2022
# 951   4/14/2023                 Good              34    4/22/2022
# 952  02/01/2022  Description Missing              65    9/20/2021
# 953   9/15/2022                 Good              25    9/23/2021
# 954  05/01/2023  Description Missing              20   11/07/2022
# 955   7/20/2022            Excellent               7    4/21/2022
# 956   8/12/2021            Excellent               8    5/13/2021
# 957  12/31/2023            Excellent              14    2/10/2023
#
#      Listing_Price   ML# REO Sold_Price             Style Unit_on_Floor_#  \
# 938         205000  2825   N     220000  Garden Apartment             2.0
# 939         239900   468   N     227000         Townhouse             1.0
# 940         124900  1363   N     135000  Garden Apartment             2.0
# 941         285000  9501   N     285000         Townhouse             1.0
# 942         244990  8266   N     235000         Townhouse             2.0
# 943         289999  7496   N     295000         Townhouse             1.0
# 944         309000  7089   N     320000         Townhouse             1.0
# 945         315000   980   N     350000         Townhouse             1.0
# 946         185000  7222   N     185500             Other             1.0
# 947         200000  3608   N     215000             Other             1.0
# 948         235000  7761   N     258000             Other             1.0
# 949         279000  2953   N     265000         Townhouse             1.0
# 950         239000   498   N     200000         Townhouse             1.0
# 951         239000  5763   N     220000         Townhouse             1.0
# 952         249000    33   N     242000         Townhouse             1.0
# 953         194999  9710   N     195000         Townhouse             2.0
# 954         129999  7393   N     135000  Garden Apartment             2.0
# 955         265000  1172   N     265000  Garden Apartment             1.0
# 956         210000  2589   N     207000  Garden Apartment             2.0
# 957         339000   253   N     359000         Townhouse             1.0
#
#            Development  Bath  Bedrooms Contract_Date  count    Year  \
# 938        Port Regina   1.0         1    2022-05-11   10.0  2022.0
# 939  East Isabellaport   1.5         2    2023-01-31   33.0  2023.0
# 940         Davidburgh   1.0         1    2022-03-16   24.0  2022.0
# 941  East Isabellaport   1.5         3    2023-06-22   33.0  2023.0
# 942  East Isabellaport   1.5         3    2022-10-18   33.0  2022.0
# 943       Bradfordberg   1.0         2    2022-12-30   33.0  2022.0
# 944       Bradfordberg   1.0         2    2023-03-24   33.0  2023.0
# 945       Bradfordberg   1.0         2    2023-06-22   33.0  2023.0
# 946         New Sophia   1.0         1    2021-10-05   54.0  2021.0
# 947         New Sophia   1.0         1    2022-07-12   54.0  2022.0
# 948         New Sophia   1.0         2    2021-07-28   54.0  2021.0
# 949  East Isabellaport   1.5         3    2022-09-20   33.0  2022.0
# 950  East Isabellaport   1.5         2    2022-09-27   33.0  2022.0
# 951  East Isabellaport   1.5         2    2022-05-26   33.0  2022.0
# 952  East Isabellaport   1.5         3    2021-11-24   33.0  2021.0
# 953  East Isabellaport   1.5         2    2021-10-18   33.0  2021.0
# 954         Davidburgh   1.0         1    2022-11-28   24.0  2022.0
# 955        Port Regina   1.0         2    2022-05-12   10.0  2022.0
# 956        Port Regina   1.0         1    2021-06-01   10.0  2021.0
# 957       Bradfordberg   1.0         2    2023-02-24   33.0  2023.0
#
#     Month_Year  Month
# 938    05-2022      5
# 939    01-2023      1
# 940    03-2022      3
# 941    06-2023      6
# 942    10-2022     10
# 943    12-2022     12
# 944    03-2023      3
# 945    06-2023      6
# 946    10-2021     10
# 947    07-2022      7
# 948    07-2021      7
# 949    09-2022      9
# 950    09-2022      9
# 951    05-2022      5
# 952    11-2021     11
# 953    10-2021     10
# 954    11-2022     11
# 955    05-2022      5
# 956    06-2021      6
# 957    02-2023      2

# %% [markdown]
# # Pre-Processing

# %%
# fix the olumn names
condo.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
# purge duplicate ML#s
condo = condo.drop_duplicates(subset=['ML#'], keep='first')

# %%
# prompt: drop any rows where ther sold price is null

condo.dropna(subset=['Sold_Price'], inplace=True)
# Out:
# <ipython-input-8-618774c0c9de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo.dropna(subset=['Sold_Price'], inplace=True)

# %%
# select columns

condo = condo[['ML#', 'Style','Development','Sold_Price',
                   'Bath','Bedrooms','Appearance',
                'Unit_on_Floor_#','Contract_Date','Days_On_Market',
                'Listing_Price','Exp_Date']]

# %%
# Ensure the column is treated as a string or categorical
condo['Unit_on_Floor_#'] = condo['Unit_on_Floor_#'].astype(str)

# %%
value_counts = condo['Unit_on_Floor_#'].value_counts(dropna=False)
value_counts
# Out:
# 1      558
# 2      161
# 1.0     88
# 2.0     52
# nan     12
# 0       12
# 3        8
# 4        6
# 11       2
# 13       1
# B        1
# 231      1
# 71       1
# 93       1
# 33       1
# 0.0      1
# 40       1
# Name: Unit_on_Floor_#, dtype: int64

# %%
# Agents are more likely to omit Floor Number if it is ont he ground
# than if ioon the 2nd
#
condo['Unit_on_Floor_#'] = condo['Unit_on_Floor_#'].replace(0, 1)

# %%
condo['Unit_on_Floor_#'] = condo['Unit_on_Floor_#'].fillna(1)

# %%
# Drop rows where 'Unit_on_Floor_#' contains 'B'
#condo = condo[condo['Unit_on_Floor_#'] != 'B']
condo = condo[~condo['Unit_on_Floor_#'].str.contains('\.')]

# %%
# #Similarly Agents are more likely to omit if it
# # is a 1 bedroom than 2.
# # none are studios

# # Then, convert the column to integers
# condo['Unit_on_Floor_#'] = condo['Unit_on_Floor_#'].astype(int)

# # Convert 'Bedrooms' to a categorical data type
# condo['Unit_on_Floor_#'] = condo['Unit_on_Floor_#'].astype('category')

# %%
condo.shape
# Out:
# (766, 12)

# %% [markdown]
# # Developments

# %%
condo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 766 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ML#              766 non-null    int64
#  1   Style            764 non-null    object
#  2   Development      766 non-null    object
#  3   Sold_Price       766 non-null    object
#  4   Bath             766 non-null    float64
#  5   Bedrooms         766 non-null    int64
#  6   Appearance       766 non-null    object
#  7   Unit_on_Floor_#  766 non-null    object
#  8   Contract_Date    766 non-null    object
#  9   Days_On_Market   766 non-null    int64
#  10  Listing_Price    766 non-null    int64
#  11  Exp_Date         763 non-null    object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 77.8+ KB

# %%
dev_counts = condo['Development'].value_counts(dropna=False)
dev_counts
# Out:
# Port Barbaraport     79
# East Melissa         70
# New Heidimouth       63
# Jodifort             49
# Port Michael         49
# New Bonnie           46
# East Michaelstad     44
# North Mikefort       32
# Sarabury             30
# East Kennethfurt     28
# Allisonville         25
# Stewartport          23
# East Christopher     20
# Angelaport           17
# New Ashley           17
# Cindyborough         16
# Hernandezstad        15
# East Charlesmouth    14
# West Joanna          14
# Lake Aaron           13
# Griffinton           12
# Port Amy             12
# East John            12
# Walkershire          12
# Lisaberg             11
# New Moniqueview      11
# Port David           10
# Williamsland          9
# Bradfordberg          6
# Port Stacyfort        4
# Davidburgh            2
# New Sophia            1
# Name: Development, dtype: int64

# %%
# Developments = sorted(condo['Development'].unique())
# Developments

# %% [markdown]
# If some of the Developments were redundant becasue of typos we would consolidate them like this

# %%
# condo['Development'] = condo['Development'].replace(['Green Village',
#  'Greenwood',
#  'Greenwood Realty',
#  'Greenwood Vill',
#  'Greenwood Villag',
#  'Greenwood Village',
#  'Greenwood Village 55+',
#  'Greenwood Villagge',
#  'Greenwood Villiage'], 'Greenwood Village')

## Here all of the versions would become 'Greenwood Village'

# %% [markdown]
# # We will look at just the one development

# %%
condo = condo[condo['Development'] == 'Port Barbaraport']
condo
# Out:
#       ML#             Style       Development Sold_Price  Bath  Bedrooms  \
# 7    7843         Townhouse  Port Barbaraport     242000   1.5         2
# 8    9250             Other  Port Barbaraport     275000   1.0         1
# 17   7972             Other  Port Barbaraport     265000   2.0         2
# 20   7464             Other  Port Barbaraport     300000   1.5         2
# 31   4537             Other  Port Barbaraport     262000   1.5         1
# 33   5555             Other  Port Barbaraport     285000   1.5         3
# 44   8293             Other  Port Barbaraport     288000   1.0         1
# 57   3139             Other  Port Barbaraport     295000   2.0         2
# 64    453  Garden Apartment  Port Barbaraport     300000   1.0         2
# 71   8326             Other  Port Barbaraport     292000   1.0         2
# 328  1267             Other  Port Barbaraport     300000   2.0         2
# 331  5059             Other  Port Barbaraport     285000   1.0         2
# 332   632         Townhouse  Port Barbaraport     365000   2.5         3
# 334  6762             Other  Port Barbaraport     310000   1.0         2
# 337  7400             Other  Port Barbaraport     330000   2.0         2
# 338   708             Other  Port Barbaraport     330000   2.0         2
# 340  9486             Other  Port Barbaraport     350000   1.5         2
# 342  9507         Townhouse  Port Barbaraport     355000   1.5         3
# 343  3966             Other  Port Barbaraport     360000   2.0         2
# 345  1135             Other  Port Barbaraport     320000   2.0         2
# 347  3078         Townhouse  Port Barbaraport     291000   1.5         3
# 348  8173             Other  Port Barbaraport     320000   1.0         2
# 349  5722  Garden Apartment  Port Barbaraport     370000   1.5         2
# 350  4989         Townhouse  Port Barbaraport     371000   2.0         3
# 352  3977             Other  Port Barbaraport     340000   2.0         2
# 359  6595         Townhouse  Port Barbaraport     369990   2.5         3
# 362  9384         Townhouse  Port Barbaraport     420000   2.5         3
# 363  4124  Garden Apartment  Port Barbaraport     220000   2.0         2
# 366  7011         Townhouse  Port Barbaraport     276000   1.5         2
# 369  1375             Other  Port Barbaraport     325000   2.0         2
# 370   647         Townhouse  Port Barbaraport     375000   2.5         3
# 374  4137         Townhouse  Port Barbaraport     360000   1.5         2
# 378  9388         Townhouse  Port Barbaraport     410000   2.5         3
# 379  1794             Other  Port Barbaraport     345000   2.0         2
# 383  8971         Townhouse  Port Barbaraport     365000   2.5         3
# 385  3126             Other  Port Barbaraport     355000   2.5         3
# 387  1350         Townhouse  Port Barbaraport     330000   1.5         2
# 390  6070         Townhouse  Port Barbaraport     390000   2.5         3
# 391  8884         Townhouse  Port Barbaraport     325000   1.5         2
# 402  4487             Other  Port Barbaraport     316000   1.5         2
# 403  5114             Other  Port Barbaraport     380000   2.5         3
# 407  4812             Other  Port Barbaraport     258000   1.0         2
# 409  4566         Townhouse  Port Barbaraport     277000   1.0         1
# 410  9452             Other  Port Barbaraport     360000   1.5         3
# 412  2537             Other  Port Barbaraport     382500   2.0         2
# 414  1173             Other  Port Barbaraport     280000   1.5         1
# 415  8465             Other  Port Barbaraport     375000   2.0         2
# 416  6890         Townhouse  Port Barbaraport     329000   1.5         2
# 419   322             Other  Port Barbaraport     380000   2.0         2
# 420  4677             Other  Port Barbaraport     325000   1.5         2
# 421  2665         Townhouse  Port Barbaraport     360000   2.0         2
# 423  1109             Other  Port Barbaraport     350000   1.0         2
# 425  2659             Other  Port Barbaraport     370000   2.0         2
# 429  6284             Other  Port Barbaraport     389000   2.5         3
# 430  2117             Other  Port Barbaraport     395000   2.5         3
# 432  3389             Other  Port Barbaraport     370000   1.5         2
# 434   882             Other  Port Barbaraport     317500   2.0         2
# 436  9094         Townhouse  Port Barbaraport     395000   2.5         3
# 437  3427             Other  Port Barbaraport     340000   2.0         2
# 438  2328         Townhouse  Port Barbaraport     305000   1.0         2
# 439  2245             Other  Port Barbaraport     360000   1.5         2
# 440  4532         Townhouse  Port Barbaraport     347000   1.5         2
# 441  6456             Other  Port Barbaraport     312000   2.0         2
# 443  7887         Townhouse  Port Barbaraport     360000   1.5         2
# 444  6364         Townhouse  Port Barbaraport     345000   2.0         2
# 445  3968             Other  Port Barbaraport     377500   2.0         2
# 447  2482         Townhouse  Port Barbaraport     400000   1.5         3
# 449    29             Other  Port Barbaraport     344000   2.0         2
# 450  3896             Other  Port Barbaraport     350000   2.0         2
# 452  2071         Townhouse  Port Barbaraport     389000   1.5         3
# 454  5011         Townhouse  Port Barbaraport     395000   1.5         3
# 458  5584         Townhouse  Port Barbaraport     355000   1.5         2
# 460  3597             Other  Port Barbaraport     349000   2.0         2
# 462  6393  Garden Apartment  Port Barbaraport     327000   2.0         2
# 464    77             Other  Port Barbaraport     367500   1.5         2
# 468  6647  Garden Apartment  Port Barbaraport     370000   2.0         2
# 472  9253             Other  Port Barbaraport     375000   1.5         3
# 474  4863             Other  Port Barbaraport     360000   1.0         2
# 478  4266             Other  Port Barbaraport     336000   1.0         2
#
#               Appearance Unit_on_Floor_# Contract_Date  Days_On_Market  \
# 7    Description Missing               1    2022-07-29               3
# 8    Description Missing               1    2022-07-25               5
# 17   Description Missing               2    2022-08-30              19
# 20                  Mint               1    2022-09-30              36
# 31             Excellent               1    2022-10-06               5
# 33   Description Missing               1    2022-10-06               2
# 44                  Mint               1    2023-02-24              91
# 57   Description Missing               2    2023-03-03              59
# 64   Description Missing               2    2023-03-23              12
# 71             Excellent               1    2023-05-02              12
# 328                 Good               1    2022-02-17              20
# 331                 Mint               1    2022-03-02              28
# 332  Description Missing               2    2022-03-07              15
# 334                 Mint               1    2022-04-11              57
# 337  Description Missing               2    2022-03-16               1
# 338                 Mint               1    2022-04-01              33
# 340  Description Missing               1    2022-03-18              10
# 342  Description Missing               1    2022-03-19              10
# 343  Description Missing               1    2022-03-28              19
# 345  Description Missing               1    2022-03-21              11
# 347  Description Missing               1    2022-05-19              72
# 348  Description Missing               1    2022-04-01               7
# 349                 Mint               1    2022-03-23               9
# 350            Excellent               1    2022-04-27              43
# 352            Excellent               1    2022-04-07              10
# 359            Excellent               1    2022-04-25              22
# 362            Excellent               1    2022-08-26             144
# 363  Description Missing               1    2022-04-26              21
# 366                 Good               1    2022-04-29              18
# 369                 Mint               2    2022-04-25              11
# 370  Description Missing               1    2022-05-01              15
# 374                 Mint               0    2022-07-21              87
# 378                 Mint               0    2022-05-16              12
# 379            Excellent               1    2022-05-23              21
# 383            Excellent               1    2022-08-29             111
# 385  Description Missing               2    2022-10-03             145
# 387  Description Missing               1    2022-05-26              10
# 390                 Mint               1    2022-06-08              12
# 391  Description Missing               1    2022-09-20             119
# 402  Description Missing               1    2022-06-09               2
# 403  Description Missing               1    2022-08-22              74
# 407  Description Missing               2    2022-07-12              26
# 409                 Mint               1    2022-07-11              24
# 410  Description Missing               1    2022-08-03              47
# 412  Description Missing               1    2022-07-06              15
# 414            Excellent               1    2022-07-11              12
# 415  Description Missing               1    2022-07-27              28
# 416  Description Missing               1    2022-08-16              38
# 419  Description Missing               1    2022-08-02              18
# 420                 Mint               1    2022-08-01              16
# 421                 Mint               2    2022-08-30              33
# 423                 Mint               1    2022-08-23              21
# 425  Description Missing               1    2022-09-07              29
# 429  Description Missing               2    2023-01-19             145
# 430                 Mint               1    2022-10-20              38
# 432  Description Missing               1    2022-10-04              18
# 434            Excellent               1    2022-10-24              32
# 436            Excellent               1    2022-12-12              56
# 437  Description Missing               4    2022-11-13              10
# 438                 Mint               2    2022-11-16              12
# 439  Description Missing               1    2023-02-01              86
# 440  Description Missing               1    2022-11-28              19
# 441  Description Missing               2    2022-12-12              76
# 443  Description Missing               1    2023-01-03              32
# 444                 Mint               1    2023-03-09              97
# 445                 Mint               1    2023-01-04              29
# 447                 Mint               1    2023-02-14              64
# 449  Description Missing               1    2023-01-20              35
# 450                 Mint               1    2023-02-21              56
# 452  Description Missing               1    2023-01-17              15
# 454  Description Missing               1    2023-01-31              14
# 458  Description Missing               1    2023-03-01              21
# 460                 Mint               1    2023-03-17              31
# 462            Excellent               1    2023-04-03              24
# 464                 Mint               1    2023-03-31              49
# 468                 Mint               2    2023-04-07               3
# 472  Description Missing               2    2023-05-08               4
# 474                 Mint               1    2023-05-10              20
# 478  Description Missing               2    2023-07-10              15
#
#      Listing_Price    Exp_Date
# 7           229000  10/20/2022
# 8           249000   7/20/2023
# 17          315000   8/11/2023
# 20          319000   2/25/2023
# 31          249000  10/31/2023
# 33          285000   4/15/2023
# 44          294990   5/25/2023
# 57          315000   1/03/2024
# 64          274999   9/10/2023
# 71          274900  12/31/2023
# 328         300000   7/28/2022
# 331         295500   2/02/2023
# 332         359000   7/17/2022
# 334         320000   8/30/2022
# 337         325000   9/01/2022
# 338         335000   8/30/2022
# 340         355000   8/31/2022
# 342         365000   2/18/2023
# 343         340000   9/09/2022
# 345         299000   8/31/2022
# 347         320000   8/31/2022
# 348         309000   9/15/2022
# 349         325000   9/14/2022
# 350         369000   9/15/2022
# 352         309999   9/23/2022
# 359         369990   4/01/2023
# 362         400000  12/31/2022
# 363         175000   9/04/2022
# 366         254900   7/09/2022
# 369         325000   4/14/2023
# 370         385000   4/16/2023
# 374         349900  11/25/2022
# 378         399990  10/29/2022
# 379         329999   8/02/2022
# 383         340000  10/10/2022
# 385         369990  11/30/2022
# 387         314000  10/31/2022
# 390         389900  11/21/2022
# 391         349900   9/30/2022
# 402         310000   6/07/2023
# 403         379000  12/31/2022
# 407         275000  12/16/2022
# 409         269000   9/17/2022
# 410         349000  12/17/2022
# 412         395000   6/21/2023
# 414         269990  12/31/2022
# 415         388000   6/27/2023
# 416         329000   7/08/2023
# 419         389000   7/15/2023
# 420         325000   7/16/2023
# 421         349900   1/31/2023
# 423         359000   2/02/2023
# 425         359000   2/09/2023
# 429         390000   8/27/2023
# 430         389000   4/30/2023
# 432         379000  10/12/2022
# 434         334900   3/21/2023
# 436         414999   6/17/2023
# 437         349000   6/02/2023
# 438         299999   1/06/2023
# 439         369000  12/04/2022
# 440         349000  12/01/2022
# 441         334999   9/27/2023
# 443         369000   1/10/2023
# 444         360000   6/01/2023
# 445         385000   6/01/2023
# 447         389900   5/31/2023
# 449         349990  12/16/2023
# 450         349989   6/16/2023
# 452         389000   2/15/2023
# 454         399000   3/01/2023
# 458         350000   8/08/2023
# 460         349000   2/13/2024
# 462         329000   8/31/2023
# 464         349999   8/09/2023
# 468         339000  10/31/2023
# 472         349999   4/10/2024
# 474         354999  10/20/2023
# 478         309990   2/29/2024

# %%
condo.shape
# Out:
# (79, 12)

# %% [markdown]
# # Appearance

# %%
# get list of all Appearance descriptions
Appearance_terms = sorted(condo['Appearance'].unique())
Appearance_terms
# Out:
# ['Description Missing', 'Excellent', 'Good', 'Mint']

# %% [markdown]
# ## Again if there were lots of Appearance types we would consolidate them as we did with the Devlopments

# %%
# condo['Appearance'] = condo['Appearance'].replace(['6M Mint', 'Exc/Mint', 'MINT',
#  'MINT +',
#  'MINT ++',
#  'MINT!',
#  'MINT++',
#  'Mint',
#  'Mint *',
#  'Mint +',
#  'Mint ++',
#  'Mint +++',
#  'Mint ++++',
#  'Mint+',
#  'Mint++',
#  'Mint+++','DIAMOND',
#  'DIAMOND++',
#  'DIAMOND+++',
#  'DIamond',
#  'Diam',
#  'Diamnond++',
#  'Diamod',
#  'Diamond',
#  'Diamond +',
#  'Diamond ++',
#  'Diamond+',
#  'Diamond++',
#  'Diamond+++', 'diamond',
#  'diamond +',
#  'diamond ++',
#  'diamond!!',
#  'diamond+','mINT',
#  'mint',
#  'mint +',
#  'mint+',
#  'mint++',
#  'mint+++',
#  'mlnt++','Perfect',
#  'Prestine',
#  'Pristene',
#  'Pristine',
#  'Superb',
#  'munt ++','pristene',
#  'pristine','perfect','Beautiful', 'Gorgeous','New',
#  'See Pics!','Like New','Amazing',
#  'Diamond Aa',
#  'New /Mint'], "Mint")

# %% [markdown]
# # Bedrooms

# %%
condo['Bedrooms'].fillna(1, inplace=True)

# Then, convert the column to integers
condo['Bedrooms'] = condo['Bedrooms'].astype(int)

# Convert 'Bedrooms' to a categorical data type
condo['Bedrooms'] = condo['Bedrooms'].astype('category')

# %% [markdown]
# # Every unit must have at least 1 Full Bath

# %%
condo['Bath'].fillna(1, inplace=True)

# %% [markdown]
# # Dates
#
# Here we mutate teh date into something more usefull

# %%
condo['Contract_Date'] = pd.to_datetime(condo['Contract_Date'])
condo['Year'] = condo['Contract_Date'].dt.year

# %%
condo['Month_Year'] = condo['Contract_Date'].dt.strftime('%m-%Y')

# %%
condo['Month'] = condo['Contract_Date'].dt.strftime('%m')

# %%
condo['Month_Year'] = pd.to_datetime(condo['Month_Year'])

# %% [markdown]
# # Days On Mkt

# %%
condo['Days_On_Market'] = condo['Days_On_Market'].astype(int)

# %%
condo.shape
# Out:
# (79, 15)

# %%
condo['Sold_Price'] = pd.to_numeric(condo['Sold_Price'])

# %% [markdown]
# # Plot

# %%
condo.shape
# Out:
# (79, 15)

# %% [markdown]
# # Drop Down Menus

# %%
#6

import plotly.graph_objects as go
import plotly.express as px
import pandas as pd  # Make sure to import pandas

# Convert 'Sold_Price' to numeric
condo['Sold_Price'] = pd.to_numeric(condo['Sold_Price'])

# Create a color mapping dictionary
color_mapping = {
    'Mint': 'green',
    'Description Missing': 'red',
    'Excellent': 'blue',
    'Good': 'orange'
}

# Create the scatter plot first
fig = px.scatter(data_frame=condo, x='Month_Year', y='Sold_Price', color='Appearance',
                 title='Bedrooms and Bath Count v Sold Price',
                 labels={'Development': 'Development', 'Sold_Price': 'Sold Price', 'Town': 'Town'},
                 hover_data=['Development', 'ML#'])

# Remove the default legend
fig.update_traces(showlegend=False)

# Add legend entries as separate scatter traces
for appearance, color in color_mapping.items():
    fig.add_trace(go.Scatter(x=[None], y=[None], mode='markers',
                             marker=dict(size=10, color=color), name=appearance))

# Update the layout for the desired width and height
fig.update_layout(width=1000, height=600)

# Add dropdown menus for Bedrooms and Baths
fig.update_layout(updatemenus=[
    dict(type='dropdown',
         x=1.15,
         y=0.7,
         buttons=[
             dict(label='All Bedrooms',
                  method='update',
                  args=[{'visible': [True] * len(condo)},
                        {'title': 'All Bedrooms: Sold Price v Condition'}]),
             dict(label='2 Bedrooms',
                  method='update',
                  args=[{'visible': [bedrooms == 2 for bedrooms in condo['Bedrooms']]},
                        {'title': 'Two Bedrooms: Sold Price v Condition'}]),
             dict(label='1 Bedroom',
                  method='update',
                  args=[{'visible': [bedrooms == 1 for bedrooms in condo['Bedrooms']]},
                        {'title': 'One Bedroom: Sold Price v Condition'}]),
         ]),
    dict(type='dropdown',
         x=1.15,
         y=0.6,
         buttons=[
             dict(label='All Baths',
                  method='update',
                  args=[{'visible': [True] * len(condo)},
                        {'title': 'All Baths: Sold Price v Condition'}]),
             dict(label='1 Bath',
                  method='update',
                  args=[{'visible': [bath == 1 for bath in condo['Bath']]},
                        {'title': 'One Bath: Sold Price v Condition'}]),
             dict(label='2 Baths',
                  method='update',
                  args=[{'visible': [bath == 2 for bath in condo['Bath']]},
                        {'title': 'Two Baths: Sold Price v Condition'}]),
         ]),
])

# Update the x-axis tick format to show both month and year with monthly tick marks
fig.update_layout(xaxis=dict(tickangle=45, tickformat='%b %Y', dtick='M3'))

# Set custom y-axis tick marks starting at 200,000 with intervals of 50,000
fig.update_layout(yaxis=dict(tickmode='linear', tick0=200000, dtick=25000))

# Change the background color
fig.update_layout(plot_bgcolor='lightblue')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f59d87cf-93e8-43c8-9061-31a0f66ab121" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f59d87cf-93e8-43c8-9061-31a0f66ab121")) {                    Plotly.newPlot(                        "f59d87cf-93e8-43c8-9061-31a0f66ab121",                        [{"customdata":[["Port Barbaraport",7843],["Port Barbaraport",9250],["Port Barbaraport",7972],["Port Barbaraport",5555],["Port Barbaraport",3139],["Port Barbaraport",453],["Port Barbaraport",632],["Port Barbaraport",7400],["Port Barbaraport",9486],["Port Barbaraport",9507],["Port Barbaraport",3966],["Port Barbaraport",1135],["Port Barbaraport",3078],["Port Barbaraport",8173],["Port Barbaraport",4124],["Port Barbaraport",647],["Port Barbaraport",3126],["Port Barbaraport",1350],["Port Barbaraport",8884],["Port Barbaraport",4487],["Port Barbaraport",5114],["Port Barbaraport",4812],["Port Barbaraport",9452],["Port Barbaraport",2537],["Port Barbaraport",8465],["Port Barbaraport",6890],["Port Barbaraport",322],["Port Barbaraport",2659],["Port Barbaraport",6284],["Port Barbaraport",3389],["Port Barbaraport",3427],["Port Barbaraport",2245],["Port Barbaraport",4532],["Port Barbaraport",6456],["Port Barbaraport",7887],["Port Barbaraport",29],["Port Barbaraport",2071],["Port Barbaraport",5011],["Port Barbaraport",5584],["Port Barbaraport",9253],["Port Barbaraport",4266]],"hovertemplate":"Appearance=Description Missing\u003cbr\u003eMonth_Year=%{x}\u003cbr\u003eSold Price=%{y}\u003cbr\u003eDevelopment=%{customdata[0]}\u003cbr\u003eML#=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Description Missing","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Description Missing","orientation":"v","showlegend":false,"x":["2022-07-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-10-01T00:00:00","2023-03-01T00:00:00","2023-03-01T00:00:00","2022-03-01T00:00:00","2022-03-01T00:00:00","2022-03-01T00:00:00","2022-03-01T00:00:00","2022-03-01T00:00:00","2022-03-01T00:00:00","2022-05-01T00:00:00","2022-04-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-10-01T00:00:00","2022-05-01T00:00:00","2022-09-01T00:00:00","2022-06-01T00:00:00","2022-08-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-07-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2023-01-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2023-02-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-01-01T00:00:00","2023-01-01T00:00:00","2023-01-01T00:00:00","2023-03-01T00:00:00","2023-05-01T00:00:00","2023-07-01T00:00:00"],"xaxis":"x","y":[242000,275000,265000,285000,295000,300000,365000,330000,350000,355000,360000,320000,291000,320000,220000,375000,355000,330000,325000,316000,380000,258000,360000,382500,375000,329000,380000,370000,389000,370000,340000,360000,347000,312000,360000,344000,389000,395000,355000,375000,336000],"yaxis":"y","type":"scatter"},{"customdata":[["Port Barbaraport",7464],["Port Barbaraport",8293],["Port Barbaraport",5059],["Port Barbaraport",6762],["Port Barbaraport",708],["Port Barbaraport",5722],["Port Barbaraport",1375],["Port Barbaraport",4137],["Port Barbaraport",9388],["Port Barbaraport",6070],["Port Barbaraport",4566],["Port Barbaraport",4677],["Port Barbaraport",2665],["Port Barbaraport",1109],["Port Barbaraport",2117],["Port Barbaraport",2328],["Port Barbaraport",6364],["Port Barbaraport",3968],["Port Barbaraport",2482],["Port Barbaraport",3896],["Port Barbaraport",3597],["Port Barbaraport",77],["Port Barbaraport",6647],["Port Barbaraport",4863]],"hovertemplate":"Appearance=Mint\u003cbr\u003eMonth_Year=%{x}\u003cbr\u003eSold Price=%{y ...
